# %%
# !pip install "pandas <3.0.0"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 12.5 MB/s  0:00:00 eta 0:00:01
# ...

# %%
from pydantic import BaseModel, Field

# %%
from pathlib import Path
import sys

repo = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(repo))
sys.path.insert(0, str(repo / "custom_components"))

from custom_components.irrigation_monitor.util import *

# %%
flume_user="onuruno.e@gmail.com"
flume_pass="hocry5-jytmec-byvVuf"
flume_client_id="93019L97TASVPN7"
flume_client_secret="RA9WBEL3N4WTXTCH1QSK"
rachio_token="0e3299ee-ca87-4c2e-b8fa-e2636c15202a"

# %%
flume_client = FlumeClient(flume_user, flume_pass, flume_client_id, flume_client_secret)

# %%
rachio_client = RachioClient(rachio_token)

# %%
rachio_client.get_last_watered_summary()
# Out:
#    zone_id                   zone_name  last_watering_start_time  \
# 0       11        11: south back fence 2026-05-01 08:00:01-07:00
# 1        9  9: Raised beds and berries 2026-05-03 06:10:02-07:00
# 2       10             10: Fruit trees 2026-03-21 20:30:02-07:00
# 3        7          7: northeast slope 2026-04-29 05:40:49-07:00
# 4        4          4: old raised beds 2025-09-23 18:01:03-07:00
# 5        5            5: Native Garden 2025-08-04 03:34:11-07:00
# 6        1          1: front succulent 2026-03-15 12:07:52-07:00
# 7       12              12: North Wall 2026-05-02 20:30:02-07:00
#
#     last_watering_stop_time  est_gallons_per_minute  est_gallons_used  sqft  \
# 0 2026-05-01 08:27:16-07:00                2.201000         59.977250   142
# 1 2026-05-03 06:11:01-07:00                4.251133          4.180281   187
# 2 2026-03-21 21:02:41-07:00               12.400000        404.860000   300
# ...

# %%
res = poll_for_irrigation_usage(
    flume_user,
    flume_pass,
    flume_client_id,
    flume_client_secret,
    rachio_token,
    flume_device_index=0,
)

# %%
res
# Out:
#                     zone_name  total_gallons  total_watering_minutes  \
# 0          7: northeast slope      18.852517                    19.0
# 1              12: North Wall      54.027080                     9.0
# 2  9: Raised beds and berries       3.568872                     1.0
# 3        11: south back fence      34.569669                    27.0
# 4          1: front succulent     411.932542                    45.0
# 5          4: old raised beds       0.564567                     1.0
# 6            5: Native Garden     509.360737                   146.0
# 7             10: Fruit trees     662.086290                    32.0
#
#    gallons_per_minute  zone_id  last_watering_start_time  \
# 0            0.992238        7 2026-04-29 05:40:49-07:00
# 1            6.003009       12 2026-05-02 20:30:02-07:00
# 2            3.568872        9 2026-05-03 06:10:02-07:00
# 3            1.280358       11 2026-05-01 08:00:01-07:00
# ...
